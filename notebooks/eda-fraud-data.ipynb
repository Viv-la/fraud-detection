# %%
import pandas as pd
import numpy as np

# Load datasets
fraud_df = pd.read_csv("data/raw/Fraud_Data.csv")
ip_df = pd.read_csv("data/raw/IpAddress_to_Country.csv")

# Basic inspection
print("Fraud Data Shape:", fraud_df.shape)
print("Missing Values:")
print(fraud_df.isnull().sum())

print("Duplicates:", fraud_df.duplicated().sum())

# Convert datetime columns
fraud_df["signup_time"] = pd.to_datetime(fraud_df["signup_time"])
fraud_df["purchase_time"] = pd.to_datetime(fraud_df["purchase_time"])

# Feature Engineering
fraud_df["hour_of_day"] = fraud_df["purchase_time"].dt.hour
fraud_df["day_of_week"] = fraud_df["purchase_time"].dt.day_name()

fraud_df["time_since_signup"] = (
    fraud_df["purchase_time"] -
    fraud_df["signup_time"]
).dt.total_seconds() / 3600

# Convert IP address
fraud_df["ip_int"] = fraud_df["ip_address"].astype(float).astype(np.int64)

ip_df["lower_bound_ip_address"] = ip_df["lower_bound_ip_address"].astype(np.int64)
ip_df["upper_bound_ip_address"] = ip_df["upper_bound_ip_address"].astype(np.int64)

# Sort data
fraud_df = fraud_df.sort_values("ip_int")
ip_df = ip_df.sort_values("lower_bound_ip_address")

# Geolocation mapping
fraud_geo = pd.merge_asof(
    fraud_df,
    ip_df,
    left_on="ip_int",
    right_on="lower_bound_ip_address",
    direction="backward"
)

fraud_geo = fraud_geo[
    fraud_geo["ip_int"] <= fraud_geo["upper_bound_ip_address"]
]

# Save processed data
fraud_geo.to_csv(
    "data/processed/fraud_data_processed.csv",
    index=False
)

print("Processed dataset saved successfully.")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 5
#       1 import pandas as pd
#       2 import numpy as np
#       3
#       4 # Load datasets
# ----> 5 fraud_df = pd.read_csv("data/raw/Fraud_Data.csv")
#       6 ip_df = pd.read_csv("data/raw/IpAddress_to_Country.csv")
#       7
#       8 # Basic inspection
#
# File c:\Users\nfepo\Downloads\10 Academy\W5n6\fraud-detection\venv\Lib\site-packages\pandas\io\parsers\readers.py:873, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, skip_blank_lines, parse_dates, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     861 kwds_defaults = _refine_defaults_read(
#     862     dialect,
#     863     delimiter,
#    (...)    869     dtype_backend=dtype_backend,
#     870 )
#     871 kwds.update(kwds_defaults)
# --> 873 return _read(filepath_or_buffer, kwds)
#
# File c:\Users\nfepo\Downloads\10 Academy\W5n6\fraud-detection\venv\Lib\site-packages\pandas\io\parsers\readers.py:300, in _read(filepath_or_buffer, kwds)
#     297 _validate_names(kwds.get("names", None))
#     299 # Create the parser.
# --> 300 parser = TextFileReader(filepath_or_buffer, **kwds)
#     302 if chunksize or iterator:
#     303     return parser
#
# File c:\Users\nfepo\Downloads\10 Academy\W5n6\fraud-detection\venv\Lib\site-packages\pandas\io\parsers\readers.py:1645, in TextFileReader.__init__(self, f, engine, **kwds)
#    1642     self.options["has_index_names"] = kwds["has_index_names"]
#    1644 self.handles: IOHandles | None = None
# -> 1645 self._engine = self._make_engine(f, self.engine)
#
# File c:\Users\nfepo\Downloads\10 Academy\W5n6\fraud-detection\venv\Lib\site-packages\pandas\io\parsers\readers.py:1904, in TextFileReader._make_engine(self, f, engine)
#    1902     if "b" not in mode:
#    1903         mode += "b"
# -> 1904 self.handles = get_handle(
#    1905     f,
#    1906     mode,
#    1907     encoding=self.options.get("encoding", None),
#    1908     compression=self.options.get("compression", None),
#    1909     memory_map=self.options.get("memory_map", False),
#    1910     is_text=is_text,
#    1911     errors=self.options.get("encoding_errors", "strict"),
#    1912     storage_options=self.options.get("storage_options", None),
#    1913 )
#    1914 assert self.handles is not None
#    1915 f = self.handles.handle
#
# File c:\Users\nfepo\Downloads\10 Academy\W5n6\fraud-detection\venv\Lib\site-packages\pandas\io\common.py:930, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     925 elif isinstance(handle, str):
#     926     # Check whether the filename is to be opened in binary mode.
#     927     # Binary mode does not support 'encoding' and 'newline'.
#     928     if ioargs.encoding and "b" not in ioargs.mode:
#     929         # Encoding
# --> 930         handle = open(
#     931             handle,
#     932             ioargs.mode,
#     933             encoding=ioargs.encoding,
#     934             errors=errors,
#     935             newline="",
#     936         )
#     937     else:
#     938         # Binary mode
#     939         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data/raw/Fraud_Data.csv'

# %%
fraud_df = pd.read_csv("../data/raw/Fraud_Data.csv")
ip_df = pd.read_csv("../data/raw/IpAddress_to_Country.csv")

# %%
fraud_df = pd.read_csv("data/raw/Fraud_Data.csv")
ip_df = pd.read_csv("data/raw/IpAddress_to_Country.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 fraud_df = pd.read_csv("data/raw/Fraud_Data.csv")
#       2 ip_df = pd.read_csv("data/raw/IpAddress_to_Country.csv")
#
# File c:\Users\nfepo\Downloads\10 Academy\W5n6\fraud-detection\venv\Lib\site-packages\pandas\io\parsers\readers.py:873, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, skip_blank_lines, parse_dates, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     861 kwds_defaults = _refine_defaults_read(
#     862     dialect,
#     863     delimiter,
#    (...)    869     dtype_backend=dtype_backend,
#     870 )
#     871 kwds.update(kwds_defaults)
# --> 873 return _read(filepath_or_buffer, kwds)
#
# File c:\Users\nfepo\Downloads\10 Academy\W5n6\fraud-detection\venv\Lib\site-packages\pandas\io\parsers\readers.py:300, in _read(filepath_or_buffer, kwds)
#     297 _validate_names(kwds.get("names", None))
#     299 # Create the parser.
# --> 300 parser = TextFileReader(filepath_or_buffer, **kwds)
#     302 if chunksize or iterator:
#     303     return parser
#
# File c:\Users\nfepo\Downloads\10 Academy\W5n6\fraud-detection\venv\Lib\site-packages\pandas\io\parsers\readers.py:1645, in TextFileReader.__init__(self, f, engine, **kwds)
#    1642     self.options["has_index_names"] = kwds["has_index_names"]
#    1644 self.handles: IOHandles | None = None
# -> 1645 self._engine = self._make_engine(f, self.engine)
#
# File c:\Users\nfepo\Downloads\10 Academy\W5n6\fraud-detection\venv\Lib\site-packages\pandas\io\parsers\readers.py:1904, in TextFileReader._make_engine(self, f, engine)
#    1902     if "b" not in mode:
#    1903         mode += "b"
# -> 1904 self.handles = get_handle(
#    1905     f,
#    1906     mode,
#    1907     encoding=self.options.get("encoding", None),
#    1908     compression=self.options.get("compression", None),
#    1909     memory_map=self.options.get("memory_map", False),
#    1910     is_text=is_text,
#    1911     errors=self.options.get("encoding_errors", "strict"),
#    1912     storage_options=self.options.get("storage_options", None),
#    1913 )
#    1914 assert self.handles is not None
#    1915 f = self.handles.handle
#
# File c:\Users\nfepo\Downloads\10 Academy\W5n6\fraud-detection\venv\Lib\site-packages\pandas\io\common.py:930, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     925 elif isinstance(handle, str):
#     926     # Check whether the filename is to be opened in binary mode.
#     927     # Binary mode does not support 'encoding' and 'newline'.
#     928     if ioargs.encoding and "b" not in ioargs.mode:
#     929         # Encoding
# --> 930         handle = open(
#     931             handle,
#     932             ioargs.mode,
#     933             encoding=ioargs.encoding,
#     934             errors=errors,
#     935             newline="",
#     936         )
#     937     else:
#     938         # Binary mode
#     939         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data/raw/Fraud_Data.csv'

# %%
import os

print("Current directory:")
print(os.getcwd())

print("\nFiles here:")
print(os.listdir())
# Out:
# Current directory:
# c:\Users\nfepo\Downloads\10 Academy\W5n6\fraud-detection\notebooks
#
# Files here:
# ['eda-fraud-data.ipynb']
